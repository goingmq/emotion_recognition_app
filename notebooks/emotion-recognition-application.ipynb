# %%
pip install numpy pandas librosa soundfile scikit-learn matplotlib tensorflow
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.15.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import numpy as np
import pandas as pd
import librosa
import soundfile as sf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
import matplotlib.pyplot as plt
import itertools
from pathlib import Path   # ← 新增，用于处理本地路径


# --------- CONFIG (LOCAL VERSION) ----------

# Notebook 位于： D:\语音识别\projects\emotion_recognition_app\notebooks
# 数据位于：     D:\语音识别\projects\emotion_recognition_app\data\ravdess

BASE_DIR = Path("..") / "data" / "ravdess"
DATA_PATH = BASE_DIR.resolve().as_posix()   # 转换成统一格式的字符串路径（重要）

print("Using data path:", DATA_PATH)

SR = 22050
N_MFCC = 40
MAX_PAD_LEN = 174
BATCH_SIZE = 32
EPOCHS = 40
TEST_SIZE = 0.2
RANDOM_STATE = 42
MODEL_OUT = "ravdess_ser_cnn.h5"

# -------------------------------------------


# RAVDESS emotion mapping
EMOTIONS = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

def extract_emotion_from_filename(filename):
    base = os.path.basename(filename)
    parts = base.split('.')[0].split('-')
    if len(parts) < 3:
        return None
    emo_code = parts[2]
    return EMOTIONS.get(emo_code)

def pad_or_truncate(mfcc, max_len=MAX_PAD_LEN):
    if mfcc.shape[1] < max_len:
        pad_width = max_len - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0,0),(0,pad_width)), mode='constant')
    else:
        mfcc = mfcc[:, :max_len]
    return mfcc

def extract_features(file_path, sr=SR, n_mfcc=N_MFCC, max_pad_len=MAX_PAD_LEN):
    try:
        y, sr = librosa.load(file_path, sr=sr)
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    delta = librosa.feature.delta(mfcc)
    delta2 = librosa.feature.delta(mfcc, order=2)

    stacked = np.vstack([mfcc, delta, delta2])
    stacked = pad_or_truncate(stacked, max_pad_len)
    return stacked


def load_dataset(data_path):
    pattern = os.path.join(data_path, '**', '*.wav')
    files = glob.glob(pattern, recursive=True)

    print(f"Found {len(files)} wav files in {data_path}")
    X, Y = [], []

    for f in files:
        emo = extract_emotion_from_filename(f)
        if emo is None:
            continue
        feat = extract_features(f)
        if feat is None:
            continue
        X.append(feat)
        Y.append(emo)

    X = np.array(X)
    Y = np.array(Y)

    print("X shape (samples, features, time):", X.shape)
    return X, Y
# Out:
# Found 2880 wav files.
# X shape (num_samples, features, time): (2880, 120, 174)
# Emotions in data: ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']
# Train shape: (2304, 120, 174, 1) (2304, 8)
# Test shape: (576, 120, 174, 1) (576, 8)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 120, 174, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 120, 174, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 120, 174, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 60, 87, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 60, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 30, 43, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 43, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 21, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,112 (434.03 KB)
#  Trainable params: 110,664 (432.28 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764086305.615342     116 service.cc:148] XLA service 0x784c5402b3b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764086305.616209     116 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1764086305.616228     116 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1764086306.055989     116 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.1751 - loss: 2.0955
# I0000 00:00:1764086310.499705     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 15s 105ms/step - accuracy: 0.2245 - loss: 1.9873 - val_accuracy: 0.1991 - val_loss: 1.9486
# Epoch 2/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4000 - loss: 1.6289 - val_accuracy: 0.2251 - val_loss: 1.9446
# Epoch 3/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4944 - loss: 1.3930 - val_accuracy: 0.1861 - val_loss: 1.9070
# Epoch 4/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5603 - loss: 1.1971 - val_accuracy: 0.2121 - val_loss: 2.0082
# Epoch 5/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6470 - loss: 0.9972 - val_accuracy: 0.2857 - val_loss: 1.7652
# Epoch 6/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6730 - loss: 0.9386 - val_accuracy: 0.4416 - val_loss: 1.7741
# Epoch 7/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7335 - loss: 0.7763 - val_accuracy: 0.5195 - val_loss: 1.3594
# Epoch 8/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7905 - loss: 0.6551 - val_accuracy: 0.4242 - val_loss: 1.2983
# Epoch 9/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8323 - loss: 0.5186 - val_accuracy: 0.6320 - val_loss: 1.0301
# Epoch 10/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8631 - loss: 0.4378 - val_accuracy: 0.5931 - val_loss: 0.9664
# Epoch 11/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8885 - loss: 0.3591 - val_accuracy: 0.6061 - val_loss: 1.1206
# Epoch 12/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9220 - loss: 0.2887 - val_accuracy: 0.6926 - val_loss: 0.9397
# Epoch 13/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9412 - loss: 0.2255 - val_accuracy: 0.9134 - val_loss: 0.2863
# Epoch 14/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9669 - loss: 0.1594 - val_accuracy: 0.8398 - val_loss: 0.4060
# Epoch 15/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9686 - loss: 0.1326 - val_accuracy: 0.8398 - val_loss: 0.4377
# Epoch 16/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9835 - loss: 0.0918 - val_accuracy: 0.7576 - val_loss: 0.7041
# Epoch 17/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9756 - loss: 0.1065 - val_accuracy: 0.8398 - val_loss: 0.4686
# Epoch 18/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9882 - loss: 0.0682 - val_accuracy: 0.8615 - val_loss: 0.4590
# Epoch 19/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9935 - loss: 0.0562 - val_accuracy: 0.7792 - val_loss: 0.6544
# Test loss: 0.2949, Test accuracy: 0.8976
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#        angry       1.00      0.95      0.97        76
#         calm       0.84      1.00      0.91        77
#      disgust       0.97      0.97      0.97        77
#      fearful       0.96      0.90      0.93        77
#        happy       0.97      0.88      0.93        77
#      neutral       0.71      0.76      0.73        38
#          sad       0.95      0.69      0.80        77
#    surprised       0.77      0.96      0.86        77
#
#     accuracy                           0.90       576
#    macro avg       0.90      0.89      0.89       576
# weighted avg       0.91      0.90      0.90       576

# %%
#----------------------------------------------
# Experiment 1: LSTM Model Only
#----------------------------------------------
print("--- Starting LSTM Model Experiment ---")


def build_lstm_model(input_shape, num_classes):
    inp = layers.Input(shape=input_shape)
    x = layers.LSTM(128, return_sequences=True)(inp)
    x = layers.Dropout(0.3)(x)
    x = layers.LSTM(64)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs=inp, outputs=out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Step 1: Load data and encode labels
X, Y = load_dataset(DATA_PATH)
le = LabelEncoder()
y_encoded = le.fit_transform(Y)
num_classes = len(le.classes_)
y_cat = tf.keras.utils.to_categorical(y_encoded, num_classes=num_classes)

# Step 2: Reshape data for LSTM (transpose)
# Shape change: (samples, features, time) -> (samples, time, features)
print("Reshaping data for LSTM...")
X_for_rnn = np.transpose(X, (0, 2, 1))
print("New data shape:", X_for_rnn.shape)

# Step 3: Split data into Train-Test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_for_rnn, y_cat, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y_encoded
)

# Step 4: Build the LSTM model
input_shape_lstm = (X_train.shape[1], X_train.shape[2]) # Shape: (time, features)
model_lstm = build_lstm_model(input_shape_lstm, num_classes)
model_lstm.summary()

cb = [
    callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
    callbacks.ModelCheckpoint(MODEL_OUT, save_best_only=True, monitor='val_loss')
]

# Step 5: Train the model
print("\n--- Starting LSTM Model Training ---")
history_lstm = model_lstm.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=cb,
    verbose=1
)

# Step 6: Evaluate the model
print("\n--- LSTM Model Evaluation ---")
loss, acc = model_lstm.evaluate(X_test, y_test, verbose=0)
print(f"LSTM Test Loss: {loss:.4f}, Test Accuracy: {acc:.4f}")

lstm_result = {'Model': 'LSTM', 'Test Accuracy': acc, 'Test Loss': loss}

# Classification report and confusion matrix
y_pred = model_lstm.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
print("\nLSTM Classification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=le.classes_))
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot Confusion Matrix (Counts)
plot_confusion_matrix(cm, classes=le.classes_, title='LSTM Confusion Matrix (Counts)')

# Plot Confusion Matrix (Normalized)
plot_confusion_matrix(cm, classes=le.classes_, normalize=True, title='LSTM Normalized Confusion Matrix')

# Plot Training & Validation Accuracy and Loss
print("\n--- Plotting Training History ---")
plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_lstm.history['accuracy'], label='Training Accuracy')
plt.plot(history_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history_lstm.history['loss'], label='Training Loss')
plt.plot(history_lstm.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# --- Starting LSTM Model Experiment ---
# Found 2880 wav files.
# X shape (num_samples, features, time): (2880, 120, 174)
# Reshaping data for LSTM...
# New data shape: (2880, 174, 120)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 174, 120)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 174, 128)       │       127,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 174, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 181,576 (709.28 KB)
#  Trainable params: 181,576 (709.28 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Starting LSTM Model Training ---
# Epoch 1/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.1806 - loss: 2.0322 - val_accuracy: 0.2857 - val_loss: 1.7940
# Epoch 2/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3226 - loss: 1.7368 - val_accuracy: 0.3290 - val_loss: 1.6984
# Epoch 3/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3388 - loss: 1.6372 - val_accuracy: 0.3593 - val_loss: 1.6149
# Epoch 4/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4073 - loss: 1.4760 - val_accuracy: 0.3939 - val_loss: 1.4757
# Epoch 5/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4537 - loss: 1.4330 - val_accuracy: 0.4762 - val_loss: 1.4033
# Epoch 6/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5118 - loss: 1.2961 - val_accuracy: 0.4892 - val_loss: 1.2926
# Epoch 7/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5303 - loss: 1.2651 - val_accuracy: 0.4892 - val_loss: 1.3492
# Epoch 8/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5584 - loss: 1.2094 - val_accuracy: 0.5714 - val_loss: 1.1730
# Epoch 9/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6250 - loss: 1.0457 - val_accuracy: 0.5887 - val_loss: 1.1617
# Epoch 10/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6549 - loss: 0.9457 - val_accuracy: 0.6104 - val_loss: 1.1056
# Epoch 11/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6967 - loss: 0.8981 - val_accuracy: 0.6017 - val_loss: 1.0532
# Epoch 12/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7255 - loss: 0.8073 - val_accuracy: 0.6320 - val_loss: 1.0775
# Epoch 13/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7309 - loss: 0.7871 - val_accuracy: 0.6623 - val_loss: 1.0956
# Epoch 14/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7619 - loss: 0.6868 - val_accuracy: 0.6494 - val_loss: 1.0208
# Epoch 15/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7620 - loss: 0.6705 - val_accuracy: 0.6753 - val_loss: 1.0146
# Epoch 16/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7882 - loss: 0.5944 - val_accuracy: 0.7056 - val_loss: 0.9192
# Epoch 17/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7862 - loss: 0.5801 - val_accuracy: 0.6320 - val_loss: 1.1105
# Epoch 18/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7904 - loss: 0.6541 - val_accuracy: 0.7100 - val_loss: 0.9927
# Epoch 19/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8205 - loss: 0.5799 - val_accuracy: 0.7186 - val_loss: 0.9390
# Epoch 20/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8442 - loss: 0.4620 - val_accuracy: 0.7273 - val_loss: 0.8941
# Epoch 21/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8077 - loss: 0.5980 - val_accuracy: 0.7576 - val_loss: 0.8913
# Epoch 22/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8569 - loss: 0.4300 - val_accuracy: 0.7749 - val_loss: 0.8237
# Epoch 23/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8683 - loss: 0.3808 - val_accuracy: 0.7576 - val_loss: 0.9369
# Epoch 24/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8652 - loss: 0.3876 - val_accuracy: 0.7922 - val_loss: 0.7424
# Epoch 25/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8701 - loss: 0.4075 - val_accuracy: 0.7229 - val_loss: 0.9405
# Epoch 26/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8713 - loss: 0.4359 - val_accuracy: 0.8052 - val_loss: 0.7033
# Epoch 27/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9001 - loss: 0.3146 - val_accuracy: 0.7922 - val_loss: 0.7337
# Epoch 28/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9136 - loss: 0.2855 - val_accuracy: 0.8095 - val_loss: 0.6983
# Epoch 29/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9347 - loss: 0.2329 - val_accuracy: 0.8182 - val_loss: 0.6876
# Epoch 30/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9345 - loss: 0.2327 - val_accuracy: 0.7965 - val_loss: 0.7627
# Epoch 31/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9273 - loss: 0.2317 - val_accuracy: 0.8052 - val_loss: 0.8461
# Epoch 32/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9295 - loss: 0.2175 - val_accuracy: 0.8485 - val_loss: 0.6570
# Epoch 33/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8927 - loss: 0.3500 - val_accuracy: 0.8182 - val_loss: 0.6442
# Epoch 34/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9308 - loss: 0.2456 - val_accuracy: 0.8312 - val_loss: 0.6666
# Epoch 35/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9516 - loss: 0.1788 - val_accuracy: 0.8139 - val_loss: 0.7849
# Epoch 36/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9300 - loss: 0.2226 - val_accuracy: 0.8052 - val_loss: 0.8638
# Epoch 37/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9422 - loss: 0.1999 - val_accuracy: 0.8009 - val_loss: 0.8588
# Epoch 38/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9433 - loss: 0.2147 - val_accuracy: 0.7965 - val_loss: 0.7926
# Epoch 39/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9457 - loss: 0.1827 - val_accuracy: 0.8139 - val_loss: 0.7390
#
# --- LSTM Model Evaluation ---
# LSTM Test Loss: 0.6197, Test Accuracy: 0.8299
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# LSTM Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.92      0.86      0.88        76
#         calm       0.87      0.92      0.89        77
#      disgust       0.82      0.90      0.86        77
#      fearful       0.93      0.74      0.83        77
#        happy       0.71      0.86      0.78        77
#      neutral       0.79      0.79      0.79        38
#          sad       0.79      0.70      0.74        77
#    surprised       0.84      0.86      0.85        77
#
#     accuracy                           0.83       576
#    macro avg       0.83      0.83      0.83       576
# weighted avg       0.84      0.83      0.83       576
# --- Plotting Training History ---

# %%
#----------------------------------------------
# Experiment 2: CNN-LSTM Hybrid Model
#----------------------------------------------
print("--- Starting CNN-LSTM Hybrid Model Experiment ---")

def build_cnn_lstm_model(input_shape, num_classes):
    # Input shape: (features, time, 1)
    inp = layers.Input(shape=input_shape)

    # CNN part for feature extraction
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)
    
    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Reshape CNN output to feed into LSTM
    current_shape = x.shape
    x = layers.Reshape((current_shape[2], current_shape[1] * current_shape[3]))(x)

    # LSTM part for sequence analysis
    x = layers.LSTM(64)(x)
    x = layers.Dropout(0.4)(x)
    
    out = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=inp, outputs=out)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Step 1: Load data and encode labels
X, Y = load_dataset(DATA_PATH)
le = LabelEncoder()
y_encoded = le.fit_transform(Y)
num_classes = len(le.classes_)
y_cat = tf.keras.utils.to_categorical(y_encoded, num_classes=num_classes)

# Step 2: Reshape data for CNN input (add channel dimension)
# Shape change: (samples, features, time) -> (samples, features, time, 1)
print("Reshaping data for CNN-LSTM...")
X_for_cnn = X[..., np.newaxis]
print("New data shape:", X_for_cnn.shape)

# Step 3: Split data into Train-Test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_for_cnn, y_cat, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y_encoded
)

# Step 4: Build the CNN-LSTM model
input_shape_cnn_lstm = (X_train.shape[1], X_train.shape[2], X_train.shape[3]) # Shape: (features, time, 1)
model_cnn_lstm = build_cnn_lstm_model(input_shape_cnn_lstm, num_classes)
model_cnn_lstm.summary()

# Define Callbacks
cb = [
    callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
    callbacks.ModelCheckpoint("ravdess_ser_cnn_lstm.h5", save_best_only=True, monitor='val_loss')
]

# Step 5: Train the model
print("\n--- Starting CNN-LSTM Model Training ---")
history_cnn_lstm = model_cnn_lstm.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=cb,
    verbose=1
)

# Step 6: Evaluate the model
print("\n--- CNN-LSTM Model Evaluation ---")
loss, acc = model_cnn_lstm.evaluate(X_test, y_test, verbose=0)
print(f"CNN-LSTM Test Loss: {loss:.4f}, Test Accuracy: {acc:.4f}")

cnn_lstm_result = {'Model': 'CNN-LSTM', 'Test Accuracy': acc, 'Test Loss': loss}


# Classification report and confusion matrix
y_pred = model_cnn_lstm.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
print("\nCNN-LSTM Classification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=le.classes_))
cm = confusion_matrix(y_true_labels, y_pred_labels)

# Plot Confusion Matrix (Counts)
plot_confusion_matrix(cm, classes=le.classes_, title='CNN-LSTM Confusion Matrix (Counts)')

# Plot Confusion Matrix (Normalized)
plot_confusion_matrix(cm, classes=le.classes_, normalize=True, title='CNN-LSTM Normalized Confusion Matrix')

# Plot Training & Validation Accuracy and Loss
print("\n--- Plotting Training History ---")
plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_cnn_lstm.history['accuracy'], label='Training Accuracy')
plt.plot(history_cnn_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history_cnn_lstm.history['loss'], label='Training Loss')
plt.plot(history_cnn_lstm.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# --- Starting CNN-LSTM Hybrid Model Experiment ---
# Found 2880 wav files.
# X shape (num_samples, features, time): (2880, 120, 174)
# Reshaping data for CNN-LSTM...
# New data shape: (2880, 120, 174, 1)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 120, 174, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 120, 174, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 120, 174, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 60, 87, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 60, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 60, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 87, 3840)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │       999,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,019,400 (3.89 MB)
#  Trainable params: 1,019,208 (3.89 MB)
#  Non-trainable params: 192 (768.00 B)
# --- Starting CNN-LSTM Model Training ---
# Epoch 1/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.1246 - loss: 2.1464 - val_accuracy: 0.1515 - val_loss: 2.0758
# Epoch 2/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.1977 - loss: 1.9691 - val_accuracy: 0.1385 - val_loss: 2.0694
# Epoch 3/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.2746 - loss: 1.8827 - val_accuracy: 0.1429 - val_loss: 2.0685
# Epoch 4/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.3227 - loss: 1.7922 - val_accuracy: 0.2814 - val_loss: 1.8790
# Epoch 5/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.3471 - loss: 1.7086 - val_accuracy: 0.2857 - val_loss: 1.8153
# Epoch 6/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.4149 - loss: 1.5872 - val_accuracy: 0.3160 - val_loss: 1.7470
# Epoch 7/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.4766 - loss: 1.4553 - val_accuracy: 0.3247 - val_loss: 1.7489
# Epoch 8/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.5751 - loss: 1.2700 - val_accuracy: 0.3290 - val_loss: 1.7034
# Epoch 9/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.6791 - loss: 1.0545 - val_accuracy: 0.4632 - val_loss: 1.4315
# Epoch 10/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.7528 - loss: 0.9003 - val_accuracy: 0.3766 - val_loss: 1.6705
# Epoch 11/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.7881 - loss: 0.7540 - val_accuracy: 0.5887 - val_loss: 1.1982
# Epoch 12/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8335 - loss: 0.6298 - val_accuracy: 0.6234 - val_loss: 1.0897
# Epoch 13/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8903 - loss: 0.4862 - val_accuracy: 0.7706 - val_loss: 0.9031
# Epoch 14/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8983 - loss: 0.4346 - val_accuracy: 0.7359 - val_loss: 0.8733
# Epoch 15/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9438 - loss: 0.3124 - val_accuracy: 0.8095 - val_loss: 0.7382
# Epoch 16/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9693 - loss: 0.2475 - val_accuracy: 0.8052 - val_loss: 0.7222
# Epoch 17/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9687 - loss: 0.2138 - val_accuracy: 0.8009 - val_loss: 0.7107
# Epoch 18/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9757 - loss: 0.1803 - val_accuracy: 0.8268 - val_loss: 0.6753
# Epoch 19/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9844 - loss: 0.1342 - val_accuracy: 0.8268 - val_loss: 0.6699
# Epoch 20/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9857 - loss: 0.1198 - val_accuracy: 0.8225 - val_loss: 0.6475
# Epoch 21/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9907 - loss: 0.0919 - val_accuracy: 0.8139 - val_loss: 0.6561
# Epoch 22/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9954 - loss: 0.0766 - val_accuracy: 0.8095 - val_loss: 0.6377
# Epoch 23/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9938 - loss: 0.0712 - val_accuracy: 0.8095 - val_loss: 0.6689
# Epoch 24/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9929 - loss: 0.0721 - val_accuracy: 0.8095 - val_loss: 0.6929
# Epoch 25/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9959 - loss: 0.0533 - val_accuracy: 0.8312 - val_loss: 0.6642
# Epoch 26/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9989 - loss: 0.0512 - val_accuracy: 0.8052 - val_loss: 0.6584
# Epoch 27/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9969 - loss: 0.0445 - val_accuracy: 0.8009 - val_loss: 0.6782
# Epoch 28/40
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9958 - loss: 0.0440 - val_accuracy: 0.8009 - val_loss: 0.6875
#
# --- CNN-LSTM Model Evaluation ---
# CNN-LSTM Test Loss: 0.6624, Test Accuracy: 0.7934
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# CNN-LSTM Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.67      0.75      0.71        76
#         calm       0.91      0.82      0.86        77
#      disgust       0.78      0.84      0.81        77
#      fearful       0.83      0.81      0.82        77
#        happy       0.74      0.78      0.76        77
#      neutral       0.91      0.76      0.83        38
#          sad       0.72      0.74      0.73        77
#    surprised       0.89      0.83      0.86        77
#
#     accuracy                           0.79       576
#    macro avg       0.81      0.79      0.80       576
# weighted avg       0.80      0.79      0.80       576
# --- Plotting Training History ---

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
from tensorflow.keras import callbacks

# ===================================================================
#         Comparison Script with Graphs
# ===================================================================

# Step 1: Prepare data shapes (Same as before)
print("Loading data once for all experiments...")
X, Y = load_dataset(DATA_PATH)
le = LabelEncoder()
y_encoded = le.fit_transform(Y)
num_classes = len(le.classes_)
y_cat = tf.keras.utils.to_categorical(y_encoded, num_classes=num_classes)

# Prepare shapes
X_cnn_shape = X[..., np.newaxis]
X_lstm_shape = np.transpose(X, (0, 2, 1))

# Storage for Results and Graphs
results = []
histories = {}       # To store training history (Loss/Acc)
class_reports = {}   # To store per-class F1 scores

cb = [callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]

# Modified Helper Function
def evaluate_and_store_results(model, X_test, y_test, model_name):
    y_pred_proba = model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate overall metrics
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    roc_auc = roc_auc_score(y_test, y_pred_proba, average='weighted', multi_class='ovr')

    results.append({
        'Model': model_name,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1-Score': f1,
        'ROC-AUC': roc_auc
    })
    
    # Capture per-class report for the graph
    report_dict = classification_report(y_true, y_pred, target_names=le.classes_, output_dict=True)
    class_reports[model_name] = report_dict

# ---------------------------
# Step 2: Run Experiments 
# ---------------------------

# --- Experiment 1: CNN ---
print("\n--- Running CNN Model Experiment ---")
X_train, X_test, y_train, y_test = train_test_split(X_cnn_shape, y_cat, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y_encoded)
model_cnn = build_cnn_model((X_train.shape[1], X_train.shape[2], 1), num_classes)
# CAPTURING HISTORY HERE
histories['CNN'] = model_cnn.fit(X_train, y_train, validation_split=0.1, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=cb, verbose=0)
evaluate_and_store_results(model_cnn, X_test, y_test, 'CNN')

# --- Experiment 2: LSTM ---
print("--- Running LSTM Model Experiment ---")
X_train, X_test, y_train, y_test = train_test_split(X_lstm_shape, y_cat, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y_encoded)
model_lstm = build_lstm_model((X_train.shape[1], X_train.shape[2]), num_classes)
# CAPTURING HISTORY HERE
histories['LSTM'] = model_lstm.fit(X_train, y_train, validation_split=0.1, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=cb, verbose=0)
evaluate_and_store_results(model_lstm, X_test, y_test, 'LSTM')

# --- Experiment 3: CNN-LSTM ---
print("--- Running CNN-LSTM Model Experiment ---")
X_train, X_test, y_train, y_test = train_test_split(X_cnn_shape, y_cat, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y_encoded)
model_cnn_lstm = build_cnn_lstm_model((X_train.shape[1], X_train.shape[2], 1), num_classes)
# CAPTURING HISTORY HERE
histories['CNN-LSTM'] = model_cnn_lstm.fit(X_train, y_train, validation_split=0.1, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=cb, verbose=0)
evaluate_and_store_results(model_cnn_lstm, X_test, y_test, 'CNN-LSTM')


# ---------------------------
# Step 3: Visualization (The Graphs You Wanted)
# ---------------------------

# --- Graph 1: Combined Model Performance Comparison (Bar Chart) ---
df_results = pd.DataFrame(results)
df_melted = df_results.melt(id_vars="Model", var_name="Metric", value_name="Score")

plt.figure(figsize=(10, 6))
sns.barplot(data=df_melted, x="Model", y="Score", hue="Metric", palette="viridis")
plt.title("Model Performance Comparison (Accuracy, F1, ROC-AUC)")
plt.ylim(0.5, 1.0) # Zoom in to see differences
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# --- Graph 2: Combined Validation Loss Curve ---
plt.figure(figsize=(10, 6))
for model_name, history in histories.items():
    plt.plot(history.history['val_loss'], label=f"{model_name} Val Loss", linewidth=2)

plt.title("Validation Loss Comparison (Overfitting Check)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# --- Graph 3: Per-Class F1-Score Comparison ---
# Preparing data for per-class plot
per_class_data = []
for model_name, report in class_reports.items():
    for label in le.classes_:
        if label in report:
            per_class_data.append({
                'Model': model_name,
                'Emotion': label,
                'F1-Score': report[label]['f1-score']
            })

df_per_class = pd.DataFrame(per_class_data)

plt.figure(figsize=(12, 6))
sns.barplot(data=df_per_class, x="Emotion", y="F1-Score", hue="Model", palette="magma")
plt.title("Per-Class F1-Score Comparison (Which model detects which emotion better?)")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# --- Final Table ---
print("\n" + "="*60)
print("             FINAL MODEL PERFORMANCE COMPARISON")
print("="*60)
# Format for display
df_display = df_results.copy()
for metric in ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC']:
    df_display[metric] = df_display[metric].apply(lambda x: f"{x * 100:.4f}%")
df_display.set_index('Model', inplace=True)
df_display.sort_values(by='Accuracy', ascending=False, inplace=True)
print(df_display)
# Out:
# Loading data once for all experiments...
# Found 2880 wav files.
# X shape (num_samples, features, time): (2880, 120, 174)
#
# --- Running CNN Model Experiment ---
# --- Running LSTM Model Experiment ---
# --- Running CNN-LSTM Model Experiment ---
# ============================================================
#              FINAL MODEL PERFORMANCE COMPARISON
# ============================================================
#           Accuracy Precision    Recall  F1-Score   ROC-AUC
# Model
# CNN       92.8819%  93.1701%  92.8819%  92.7245%  99.6401%
# LSTM      80.5556%  81.1972%  80.5556%  80.4819%  96.7290%
# CNN-LSTM  80.2083%  80.4744%  80.2083%  80.2381%  95.3031%

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

DATA_PATH="/kaggle/input/ravdess-emotional-speech-audio"

search_path = os.path.join(DATA_PATH, '**', '*.wav')
files = glob.glob(search_path, recursive=True)

if len(files) > 0:
    sample_file = files[0]  
    print(f"Generating MFCC for: {sample_file}")
    
    y, sr = librosa.load(sample_file, sr=22050)
    
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfcc, x_axis='time', sr=sr, cmap='viridis')
    plt.colorbar(format='%+2.0f dB')
    plt.title('MFCC Spectrogram (Feature Extraction)')
    plt.xlabel('Time')
    plt.ylabel('MFCC Coefficients')
    plt.tight_layout()
    
    plt.savefig('mfcc_spectrogram.png', dpi=300)
    plt.show()
    print("Graph saved as 'mfcc_spectrogram.png'. You can download it now.")
else:
    print("Error: No .wav files found in the data path provided.")
# Out:
# Generating MFCC for: /kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-01-01-01-02.wav
# Graph saved as 'mfcc_spectrogram.png'. You can download it now.
